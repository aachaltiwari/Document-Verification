# %%
# loss = [0.5842737594397134, 0.10205951956749414, 0.06593588283001763, 0.04688607117116174, 0.03814596338167764, 0.03227427803544989,  0.026099405693073226, 0.02400581935504189, 0.02102284741922813]
# cer = [0.07327006653156644, 0.04250564127581487, 0.022283407600626075, 0.03139663704001885, 0.03297855941373875, 0.021407020805108853, 0.01539891251437448, 0.01787512442461128, 0.018541246120973836]

loss = [0.09710411858461293, 0.057586649612978165, 0.044298214132578714, 0.0370143469451568, 0.033730371018397945, 0.030493631100292337, 0.02646726066854899]
cer = [0.03152117699100079,  0.029445478605890817, 0.024579159937705274, 0.021579190626825798, 0.027576884205266588, 0.023266743374099362, 0.02161423970519169]

# %%
import matplotlib.pyplot as plt

# Epochs (assuming they correspond to the indices of the data points)
epochs = range(1, len(loss) + 1)

# Plotting Training Loss
plt.figure(figsize=(12, 6))

# Plot for Training Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, loss, marker='o', color='b', label='Training Loss')
plt.title('Training Loss for TrOCR')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# plt.grid(True)
plt.legend()

# Plotting Training CER
plt.subplot(1, 2, 2)
plt.plot(epochs, cer, marker='o', color='r', label='Training CER')
plt.title('Training CER Evaluation for TrOCR')
plt.xlabel('Epochs')
plt.ylabel('CER')
# plt.grid(True)
plt.legend()

# Adjust layout and display the plot
plt.tight_layout()
plt.show()
